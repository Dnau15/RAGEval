# %%
# !nvidia-smi
# Out:
# Wed Apr 29 13:30:59 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8             15W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %rm -rf RAGEval2.0/

# %%
# !git clone https://github.com/Dnau15/RAGEval2.0.git
# Out:
# Cloning into 'RAGEval2.0'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 35 (delta 7), reused 31 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 79.57 KiB | 775.00 KiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# %cd RAGEval2.0/
# Out:
# /content/RAGEval2.0

# %%
# !pip install beir>=2.0.0 bm25s>=0.1.0 faiss-cpu>=1.7.4 jupyter>=1.0.0 matplotlib>=3.7.0 nltk>=3.8.0 numpy>=1.24.0 pandas>=2.0.0 psutil>=5.9.0 rank-bm25>=0.2.2 rouge-score>=0.1.2 scipy>=1.10.0 sentence-transformers>=2.2.0 torch>=2.0.0 tqdm>=4.65.0 transformers>=4.36.0

# %%
# !python scripts/run_all.py
# Out:
# Running 9 step(s):
#   - phase_a_first_stage
#   - next_stage_paired_boot
#   - phase_a_n_required
#   - next_stage_regression
#   - phase_b1_bioasq
#   - phase_b2_reranker
#   - phase_b3_router
#   - phase_b4_mirage
#   - phase_a_efficiency
#
# ...
#   RUN: scripts/phase_a_first_stage.py
# ...
#
# [nfcorpus] loading ...
# /content/RAGEval2.0/notebooks/datasets/nfcorpus.zip: 100% 2.34M/2.34M [00:05<00:00, 448kiB/s]
# 100% 3633/3633 [00:00<00:00, 111568.44it/s]
#   docs=3,633  queries=323
#   BM25 ...
#   Dense (MiniLM) ...
# modules.json: 100% 349/349 [00:00<00:00, 1.46MB/s]
# ...
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 720kB/s]
# README.md: 10.5kB [00:00, 27.6MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 335kB/s]
# config.json: 100% 612/612 [00:00<00:00, 3.11MB/s]
# model.safetensors: 100% 90.9M/90.9M [00:01<00:00, 88.4MB/s]
# Loading weights: 100% 103/103 [00:00<00:00, 1961.64it/s, Materializing param=pooler.dense.weight]
# ...

# %%
# !ls
